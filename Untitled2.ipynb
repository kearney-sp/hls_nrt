# %%
import rioxarray as riox

# %%
test = riox.open_rasterio("/mnt/c/Users/TBGPEA-Sean/Downloads/NEON_refl-surf-dir-ortho-mosaic/NEON_refl-surf-dir-ortho-mosaic/NEON.D10.CPER.DP3.30006.001.2020-06.basic.20220427T143718Z.RELEASE-2022/NEON_D10_CPER_DP3_523000_4524000_reflectance.h5")
# Out:
# /home/spkearney/miniconda3/envs/hls_cog2_env/lib/python3.9/site-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# /home/spkearney/miniconda3/envs/hls_cog2_env/lib/python3.9/site-packages/rioxarray/_io.py:841: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))
# /home/spkearney/miniconda3/envs/hls_cog2_env/lib/python3.9/site-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ...

# %%
test.rio.crs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8094/4078950321.py in <module>
# ----> 1 test.rio.crs
#
# AttributeError: 'list' object has no attribute 'rio'

# %%
test[2]
# Out:
# <xarray.Dataset>
# Dimensions:                            (band: 1000, x: 426, y: 1000)
# Coordinates:
#   * band                               (band) int64 1 2 3 4 ... 997 998 999 1000
#   * x                                  (x) float64 0.5 1.5 2.5 ... 424.5 425.5
#   * y                                  (y) float64 0.5 1.5 2.5 ... 998.5 999.5
#     spatial_ref                        int64 0
# Data variables:
#     CPER_Reflectance_Reflectance_Data  (band, y, x) int16 ...
# Attributes: (12/106)
#     CPER_Domain_Name:                                                        ...
#     CPER_Reflectance_Band_Window_1_Nanometers:                               ...
#     CPER_Reflectance_Band_Window_2_Nanometers:                               ...
#     CPER_Reflectance_Description:                                            ...
#     CPER_Reflectance_Metadata_Ancillary_Imagery_Aerosol_Optical_Depth_Band_Na...
# ...

# %%
len(test)
# Out:
# 3

# %%
from rasterio.plot import show
show(test[2]['CPER_Reflectance_Reflectance_Data'].isel(band=550))
# Out:
# <AxesSubplot:>
