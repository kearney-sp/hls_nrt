# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import requests 
import boto3
import rasterio as rio                    # https://rasterio.readthedocs.io/en/latest/
from rasterio.plot import show
from rasterio.session import AWSSession
from osgeo import gdal
import rioxarray                          # https://corteva.github.io/rioxarray/stable/index.html

# %%
import coiled
print('    setting up Coiled cluster')
aws=True
coiled.create_software_environment(
name="hls_cog_coiled",
conda="hls_cog2_environment.yml")
cluster = coiled.Cluster(
    name="hls_cog_coiled",
    software="kearney-sp/hls_cog_coiled",
    n_workers=1,
    worker_cpu=2,
    scheduler_cpu=2,
    backend_options={"region": "us-west-2", "spot": True})
client = Client(cluster)
display(client)
# Out:
#     setting up Coiled cluster
# Found existing software environment build, returning
# Output()
# Found software environment build
# Created fw rule: inbound [8786-8787] [0.0.0.0/0] []
# Created FW rules: coiled-dask-kearney58-148778-firewall
# Created fw rule: cluster [0-65535] [None] [coiled-dask-kearney58-148778-firewall -> coiled-dask-kearney58-148778-firewall]
# Created FW rules: coiled-dask-kearney58-148778-cluster-firewall
# Created fw rule: cluster [0-65535] [None] [coiled-dask-kearney58-148778-cluster-firewall -> coiled-dask-kearney58-148778-cluster-firewall]
# Created scheduler VM: coiled-dask-kearney58-148778-scheduler (type: t3.medium, ip: ['52.26.107.155'])
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ...

# %%
import rasterio as rio
from matplotlib.pyplot import imshow
from rasterio.session import AWSSession


s3_cred_endpoint = 'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials'
s3_cred = requests.get(s3_cred_endpoint).json()
import os
env = dict(GDAL_DISABLE_READDIR_ON_OPEN='FALSE', 
                   #AWS_NO_SIGN_REQUEST='YES',
                   GDAL_MAX_RAW_BLOCK_CACHE_SIZE='200000000',
                   GDAL_SWATH_SIZE='200000000',
                   VSI_CURL_CACHE_SIZE='200000000',
                   CPL_VSIL_CURL_ALLOWED_EXTENSIONS='TIF',
                   GDAL_HTTP_UNSAFESSL='YES',
                   GDAL_HTTP_COOKIEFILE=os.path.expanduser('~/cookies.txt'),
                   GDAL_HTTP_COOKIEJAR=os.path.expanduser('~/cookies.txt'),
                   AWS_REGION='us-west-2',
                   AWS_SECRET_ACCESS_KEY=s3_cred['secretAccessKey'],
                   AWS_ACCESS_KEY_ID=s3_cred['accessKeyId'],
                   AWS_SESSION_TOKEN=s3_cred['sessionToken'])
os.environ.update(env)

# %%
# %%time
cog = 's3://lp-prod-protected/HLSL30.020/HLS.L30.T58PHQ.2022114T230713.v2.0/HLS.L30.T58PHQ.2022114T230713.v2.0.B01.tif'
#cog = '/vsicurl/https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T13TEF.2020294T174351.v1.5.B01.tif'

with rio.open(cog) as src:
    profile = src.profile
    print(profile)
    arr = src.read(1)
imshow(arr)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsis3/lp-prod-protected/HLSL30.020/HLS.L30.T58PHQ.2022114T230713.v2.0/HLS.L30.T58PHQ.2022114T230713.v2.0.B01.tif' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/miniconda3/envs/hls_cog2_env/lib/python3.9/site-packages/rasterio/env.py in wrapper(*args, **kwds)
#     435
#     436         with env_ctor(session=session):
# --> 437             return f(*args, **kwds)
#     438
#     439     return wrapper
#
# ...

# %%
temp_creds_req
# Out:
# {'accessKeyId': 'ASIAZLX6ZES47IQ7Q6SN',
#  'secretAccessKey': 'Vuwqt1uPLLvcZ4W/qyojZwpZHQlQDQ03rBJu6GNl',
#  'sessionToken': '',
#  'expiration': '2022-04-27 00:11:32+00:00'}

# %%
nasa_hls_s3_url = 's3://lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B04.tif'
#nasa_hls_s3_url = 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TEF.2021003T174729.v2.0/HLS.S30.T13TEF.2021003T174729.v2.0.B8A.tif'

# %%
def get_temp_creds():
    temp_creds_url = 'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials'
    return requests.get(temp_creds_url).json()

# %%
s3_cred_endpoint = 'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials'
temp_creds_req = requests.get(s3_cred_endpoint).json()

session = boto3.Session(aws_access_key_id=temp_creds_req['accessKeyId'], 
                        aws_secret_access_key=temp_creds_req['secretAccessKey'],
                        aws_session_token=temp_creds_req['sessionToken'],
                        region_name='us-west-2')

# %%
import os
rio_env = rio.Env(AWSSession(session, requester_pays=True),
                  GDAL_CACHEMAX=1024000000,
                  GDAL_DISABLE_READDIR_ON_OPEN='YES',
                  CPL_VSIL_CURL_ALLOWED_EXTENSIONS='.tif',
                  GDAL_HTTP_MAX_RETRY=4,
                  GDAL_HTTP_RETRY_DELAY=0.42685866976877296,
                  GDAL_HTTP_MERGE_CONSECUTIVE_RANGES=True,
                  VSI_CACHE=False,
                  AWS_S3_ENDPOINT='s3.us-gov-west-1.amazonaws.com',
                  GDAL_HTTP_COOKIEFILE=os.path.expanduser('~/cookies.txt'),
                  GDAL_HTTP_COOKIEJAR=os.path.expanduser('~/cookies.txt'))
rio_env.__enter__()
os.environ["AWS_REQUEST_PAYER"] = "requester"

# %%
s3_url = 's3://lp-prod-protected/HLSL30.020/HLS.L30.T11SQA.2021333T181532.v2.0/HLS.L30.T11SQA.2021333T181532.v2.0.B04.tif'

#Read Cloud-Optimized GeoTIFF into rioxarray
da = rioxarray.open_rasterio(s3_url)
da_red = da.squeeze('band', drop=True)
da_red


#Plot using hvplot
da_red.hvplot.image(x='x', y='y', cmap='gray', aspect='equal')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/hls_cog2_env/lib/python3.9/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/miniconda3/envs/hls_cog2_env/lib/python3.9/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<function open at 0x7f47cc1b7310>, ('s3://lp-prod-protected/HLSL30.020/HLS.L30.T11SQA.2021333T181532.v2.0/HLS.L30.T11SQA.2021333T181532.v2.0.B04.tif',), 'r', (('sharing', False),)]
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# %%time
import os
with rio.Env(AWSSession(session),
             VSI_CACHE=True, 
             GDAL_DISABLE_READDIR_ON_OPEN='TRUE', 
             #AWS_NO_SIGN_REQUEST='YES',
             GDAL_MAX_RAW_BLOCK_CACHE_SIZE='200000000',
             GDAL_SWATH_SIZE='200000000',
             VSI_CURL_CACHE_SIZE='200000000',
             CPL_VSIL_CURL_ALLOWED_EXTENSIONS='TIF',
             GDAL_HTTP_UNSAFESSL='YES',
             GDAL_HTTP_COOKIEFILE=os.path.expanduser('~/cookies.txt'),
             GDAL_HTTP_COOKIEJAR=os.path.expanduser('~/cookies.txt'),
             AWS_REGION='us-west-2') as env:
    print(env.options)
    with rio.open(nasa_hls_s3_url, 'r') as src:
        print(src.profile)
        print(f'Overviews levels: {src.overviews(1)}')
        print(type(src))
             
        fig, ax = plt.subplots(1, figsize=(12, 12))
        show(src, cmap='YlGnBu')
# Out:
# {'VSI_CACHE': True, 'GDAL_DISABLE_READDIR_ON_OPEN': 'TRUE', 'GDAL_MAX_RAW_BLOCK_CACHE_SIZE': '200000000', 'GDAL_SWATH_SIZE': '200000000', 'VSI_CURL_CACHE_SIZE': '200000000', 'CPL_VSIL_CURL_ALLOWED_EXTENSIONS': 'TIF', 'GDAL_HTTP_UNSAFESSL': 'YES', 'GDAL_HTTP_COOKIEFILE': '/home/spkearney/cookies.txt', 'GDAL_HTTP_COOKIEJAR': '/home/spkearney/cookies.txt', 'AWS_REGION': 'us-west-2', 'AWS_ACCESS_KEY_ID': 'ASIAZLX6ZES4WWNWFFMQ', 'AWS_SECRET_ACCESS_KEY': '8Dl1yNUAauvC5n6TTt0/BDMsbzbpjYBJdTcAFNGD', 'AWS_SESSION_TOKEN': ''}
# ...

# %%
fo_url = 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/S/UH/2020/7/S2A_18SUH_20200729_0_L2A/B04.tif'

# %%
# %%time

with rio.Env(GDAL_DISABLE_READDIR_ON_OPEN='TRUE',    # https://rasterio.readthedocs.io/en/latest/topics/configuration.html
             AWS_NO_SIGN_REQUEST='YES',
             CPL_VSIL_CURL_ALLOWED_EXTENSIONS='tif'):
    with rio.open(fo_url) as src:
        print(src.profile)
        print(f'Overviews levels: {src.overviews(1)}')
        print(type(src))
        
        fig, ax = plt.subplots(1, figsize=(12, 12))
        show(src)
# Out:
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': 0.0, 'width': 10980, 'height': 10980, 'count': 1, 'crs': CRS.from_epsg(32618), 'transform': Affine(10.0, 0.0, 300000.0,
#        0.0, -10.0, 4300020.0), 'blockxsize': 1024, 'blockysize': 1024, 'tiled': True, 'compress': 'deflate', 'interleave': 'band'}
# Overviews levels: [2, 4, 8, 16]
# <class 'rasterio.io.DatasetReader'>
# CPU times: user 5.29 s, sys: 586 ms, total: 5.87 s
# Wall time: 51.1 s
